# %%
import pandas as pd

# %%
df = pd.read_csv("assets/worldcities.csv")

# %%
df.head()
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name  \
# 0      Tokyo      Tokyo  35.6870  139.7495      Japan   JP  JPN        Tōkyō
# 1    Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi  28.6100   77.2300      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  26940000.0  1156237133
# 4    admin  24973000.0  1356226629

# %%
df.shape
# Out:
# (48059, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48059 entries, 0 to 48058
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        48059 non-null  str
#  1   city_ascii  48057 non-null  str
#  2   lat         48059 non-null  float64
#  3   lng         48059 non-null  float64
#  4   country     48059 non-null  str
#  5   iso2        48026 non-null  str
#  6   iso3        48059 non-null  str
#  7   admin_name  47858 non-null  str
#  8   capital     15138 non-null  str
#  9   population  47808 non-null  float64
#  10  id          48059 non-null  int64
# dtypes: float64(3), int64(1), str(7)
# memory usage: 6.0 MB

# %%
df.columns
# Out:
# Index(['city', 'city_ascii', 'lat', 'lng', 'country', 'iso2', 'iso3',
#        'admin_name', 'capital', 'population', 'id'],
#       dtype='str')

# %%
df.describe()
# Out:
#                 lat           lng    population            id
# count  48059.000000  48059.000000  4.780800e+04  4.805900e+04
# mean      25.391265     16.247459  1.078566e+05  1.447192e+09
# std       22.982203     70.460025  6.855111e+05  2.611877e+08
# min      -54.933300   -179.600000  0.000000e+00  1.004003e+09
# 25%       12.192750    -44.156400  1.219100e+04  1.250540e+09
# 50%       30.934700     14.480300  2.091350e+04  1.380337e+09
# 75%       42.618900     77.080950  4.680850e+04  1.704000e+09
# max       81.716600    179.366700  3.778500e+07  1.934976e+09

# %%
df[["lat", "lng"]]
# Out:
#            lat       lng
# 0      35.6870  139.7495
# 1      -6.1750  106.8275
# 2      28.6100   77.2300
# 3      23.1300  113.2600
# 4      19.0761   72.8775
# ...        ...       ...
# 48054  14.7040   43.5990
# 48055 -25.4745   30.9703
# 48056 -33.9681   25.5981
# 48057 -18.9315   27.8070
# 48058  18.3420  -64.9331
#
# [48059 rows x 2 columns]

# %%
df.loc[df['population'] > 30000000]
# Out:
#       city city_ascii     lat       lng    country iso2 iso3 admin_name  \
# 0    Tokyo      Tokyo  35.687  139.7495      Japan   JP  JPN      Tōkyō
# 1  Jakarta    Jakarta  -6.175  106.8275  Indonesia   ID  IDN    Jakarta
# 2    Delhi      Delhi  28.610   77.2300      India   IN  IND      Delhi
#
#    capital  population          id
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604

# %%
df.sort_values('population', ascending=False)
# Out:
#                    city        city_ascii      lat       lng  \
# 0                 Tokyo             Tokyo  35.6870  139.7495
# 1               Jakarta           Jakarta  -6.1750  106.8275
# 2                 Delhi             Delhi  28.6100   77.2300
# 3             Guangzhou         Guangzhou  23.1300  113.2600
# 4                Mumbai            Mumbai  19.0761   72.8775
# ...                 ...               ...      ...       ...
# 48054          Al Jabīn          Al Jabin  14.7040   43.5990
# 48055         Nelspruit         Nelspruit -25.4745   30.9703
# 48056          Gqeberha          Gqeberha -33.9681   25.5981
# 48057            Lupane            Lupane -18.9315   27.8070
# 48058  Charlotte Amalie  Charlotte Amalie  18.3420  -64.9331
#
#                    country iso2 iso3          admin_name  capital  population  \
# 0                    Japan   JP  JPN               Tōkyō  primary  37785000.0
# ...
